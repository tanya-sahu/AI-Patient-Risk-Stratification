# %%
import pandas as pd
import numpy as np

df = pd.read_csv("heart_disease_uci.csv")

df.head()
# Out:
#    age     sex               cp  trestbps   chol    fbs         restecg  \
# 0   63    Male   typical angina     145.0  233.0   True  lv hypertrophy
# 1   67    Male     asymptomatic     160.0  286.0  False  lv hypertrophy
# 2   67    Male     asymptomatic     120.0  229.0  False  lv hypertrophy
# 3   37    Male      non-anginal     130.0  250.0  False          normal
# 4   41  Female  atypical angina     130.0  204.0  False  lv hypertrophy
#
#    thalch  exang  oldpeak        slope   ca               thal  target
# 0   150.0  False      2.3  downsloping  0.0       fixed defect       0
# 1   108.0   True      1.5         flat  3.0             normal       2
# 2   129.0   True      2.6         flat  2.0  reversable defect       1
# 3   187.0  False      3.5  downsloping  0.0             normal       0
# 4   172.0  False      1.4    upsloping  0.0             normal       0

# %%
df.shape
# Out:
# (920, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       920 non-null    int64
#  1   sex       920 non-null    object
#  2   cp        920 non-null    object
#  3   trestbps  861 non-null    float64
#  4   chol      890 non-null    float64
#  5   fbs       830 non-null    object
#  6   restecg   918 non-null    object
#  7   thalch    865 non-null    float64
#  8   exang     865 non-null    object
#  9   oldpeak   858 non-null    float64
#  10  slope     611 non-null    object
#  11  ca        309 non-null    float64
#  12  thal      434 non-null    object
#  13  target    920 non-null    int64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 100.8+ KB

# %%
df.isnull().sum()/len(df)*100.00
# Out:
# age          0.000000
# sex          0.000000
# cp           0.000000
# trestbps     6.413043
# chol         3.260870
# fbs          9.782609
# restecg      0.217391
# thalch       5.978261
# exang        5.978261
# oldpeak      6.739130
# slope       33.586957
# ca          66.413043
# thal        52.826087
# target       0.000000
# dtype: float64

# %%
# Numeric columns
num_cols = df.select_dtypes(include=["int64", "float64"]).columns

df[num_cols] = df[num_cols].fillna(df[num_cols].median())

# %%
cat_cols = df.select_dtypes(include=["object"]).columns

df[cat_cols] = df[cat_cols].fillna(df[cat_cols].mode().iloc[0])
# Out:
# C:\Users\Acer.DESKTOP-OGQID04\AppData\Local\Temp\ipykernel_22932\549759147.py:3: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[cat_cols] = df[cat_cols].fillna(df[cat_cols].mode().iloc[0])

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalch      0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# cp           object
# trestbps    float64
# chol        float64
# fbs            bool
# restecg      object
# thalch      float64
# exang          bool
# oldpeak     float64
# slope        object
# ca          float64
# thal         object
# target        int64
# dtype: object

# %%
categorical_cols = ["cp", "restecg", "slope", "thal"]

df = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

# %%
df.dtypes
df.isnull().sum()
# Out:
# age                         0
# sex                         0
# trestbps                    0
# chol                        0
# fbs                         0
# thalch                      0
# exang                       0
# oldpeak                     0
# ca                          0
# target                      0
# cp_atypical angina          0
# cp_non-anginal              0
# cp_typical angina           0
# restecg_normal              0
# restecg_st-t abnormality    0
# slope_flat                  0
# slope_upsloping             0
# thal_normal                 0
# thal_reversable defect      0
# dtype: int64

# %%
df.head()
# Out:
#    age     sex  trestbps   chol    fbs  thalch  exang  oldpeak   ca  target  \
# 0   63    Male     145.0  233.0   True   150.0  False      2.3  0.0       0
# 1   67    Male     160.0  286.0  False   108.0   True      1.5  3.0       2
# 2   67    Male     120.0  229.0  False   129.0   True      2.6  2.0       1
# 3   37    Male     130.0  250.0  False   187.0  False      3.5  0.0       0
# 4   41  Female     130.0  204.0  False   172.0  False      1.4  0.0       0
#
#    cp_atypical angina  cp_non-anginal  cp_typical angina  restecg_normal  \
# 0               False           False               True           False
# 1               False           False              False           False
# 2               False           False              False           False
# 3               False            True              False            True
# 4                True           False              False           False
#
#    restecg_st-t abnormality  slope_flat  slope_upsloping  thal_normal  \
# 0                     False       False            False        False
# 1                     False        True            False         True
# 2                     False        True            False        False
# 3                     False       False            False         True
# 4                     False       False             True         True
#
#    thal_reversable defect
# 0                   False
# 1                   False
# 2                    True
# 3                   False
# 4                   False

# %%
df["sex"] = df["sex"].map({"Male": 1, "Female": 0})

# %%
df.head()
# Out:
#    age  sex  trestbps   chol    fbs  thalch  exang  oldpeak   ca  target  \
# 0   63    1     145.0  233.0   True   150.0  False      2.3  0.0       0
# 1   67    1     160.0  286.0  False   108.0   True      1.5  3.0       2
# 2   67    1     120.0  229.0  False   129.0   True      2.6  2.0       1
# 3   37    1     130.0  250.0  False   187.0  False      3.5  0.0       0
# 4   41    0     130.0  204.0  False   172.0  False      1.4  0.0       0
#
#    cp_atypical angina  cp_non-anginal  cp_typical angina  restecg_normal  \
# 0               False           False               True           False
# 1               False           False              False           False
# 2               False           False              False           False
# 3               False            True              False            True
# 4                True           False              False           False
#
#    restecg_st-t abnormality  slope_flat  slope_upsloping  thal_normal  \
# 0                     False       False            False        False
# 1                     False        True            False         True
# 2                     False        True            False        False
# 3                     False       False            False         True
# 4                     False       False             True         True
#
#    thal_reversable defect
# 0                   False
# 1                   False
# 2                    True
# 3                   False
# 4                   False

# %%
df.dtypes
df.isnull().sum()
# Out:
# age                         0
# sex                         0
# trestbps                    0
# chol                        0
# fbs                         0
# thalch                      0
# exang                       0
# oldpeak                     0
# ca                          0
# target                      0
# cp_atypical angina          0
# cp_non-anginal              0
# cp_typical angina           0
# restecg_normal              0
# restecg_st-t abnormality    0
# slope_flat                  0
# slope_upsloping             0
# thal_normal                 0
# thal_reversable defect      0
# dtype: int64

# %%
bool_cols = df.select_dtypes(include=["bool"]).columns

df[bool_cols] = df[bool_cols].astype(int)

# %%
df.head()
# Out:
#    age  sex  trestbps   chol  fbs  thalch  exang  oldpeak   ca  target  \
# 0   63    1     145.0  233.0    1   150.0      0      2.3  0.0       0
# 1   67    1     160.0  286.0    0   108.0      1      1.5  3.0       2
# 2   67    1     120.0  229.0    0   129.0      1      2.6  2.0       1
# 3   37    1     130.0  250.0    0   187.0      0      3.5  0.0       0
# 4   41    0     130.0  204.0    0   172.0      0      1.4  0.0       0
#
#    cp_atypical angina  cp_non-anginal  cp_typical angina  restecg_normal  \
# 0                   0               0                  1               0
# 1                   0               0                  0               0
# 2                   0               0                  0               0
# 3                   0               1                  0               1
# 4                   1               0                  0               0
#
#    restecg_st-t abnormality  slope_flat  slope_upsloping  thal_normal  \
# 0                         0           0                0            0
# 1                         0           1                0            1
# 2                         0           1                0            0
# 3                         0           0                0            1
# 4                         0           0                1            1
#
#    thal_reversable defect
# 0                       0
# 1                       0
# 2                       1
# 3                       0
# 4                       0

# %%
df.isnull().sum()
# Out:
# age                         0
# sex                         0
# trestbps                    0
# chol                        0
# fbs                         0
# thalch                      0
# exang                       0
# oldpeak                     0
# ca                          0
# target                      0
# cp_atypical angina          0
# cp_non-anginal              0
# cp_typical angina           0
# restecg_normal              0
# restecg_st-t abnormality    0
# slope_flat                  0
# slope_upsloping             0
# thal_normal                 0
# thal_reversable defect      0
# dtype: int64

# %%
df.head()
# Out:
#    age  sex  trestbps   chol  fbs  thalch  exang  oldpeak   ca  target  \
# 0   63    1     145.0  233.0    1   150.0      0      2.3  0.0       0
# 1   67    1     160.0  286.0    0   108.0      1      1.5  3.0       2
# 2   67    1     120.0  229.0    0   129.0      1      2.6  2.0       1
# 3   37    1     130.0  250.0    0   187.0      0      3.5  0.0       0
# 4   41    0     130.0  204.0    0   172.0      0      1.4  0.0       0
#
#    cp_atypical angina  cp_non-anginal  cp_typical angina  restecg_normal  \
# 0                   0               0                  1               0
# 1                   0               0                  0               0
# 2                   0               0                  0               0
# 3                   0               1                  0               1
# 4                   1               0                  0               0
#
#    restecg_st-t abnormality  slope_flat  slope_upsloping  thal_normal  \
# 0                         0           0                0            0
# 1                         0           1                0            1
# 2                         0           1                0            0
# 3                         0           0                0            1
# 4                         0           0                1            1
#
#    thal_reversable defect
# 0                       0
# 1                       0
# 2                       1
# 3                       0
# 4                       0

# %%
df.dtypes
# Out:
# age                           int64
# sex                           int64
# trestbps                    float64
# chol                        float64
# fbs                           int64
# thalch                      float64
# exang                         int64
# oldpeak                     float64
# ca                          float64
# target                        int64
# cp_atypical angina            int64
# cp_non-anginal                int64
# cp_typical angina             int64
# restecg_normal                int64
# restecg_st-t abnormality      int64
# slope_flat                    int64
# slope_upsloping               int64
# thal_normal                   int64
# thal_reversable defect        int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# age                         0
# sex                         0
# trestbps                    0
# chol                        0
# fbs                         0
# thalch                      0
# exang                       0
# oldpeak                     0
# ca                          0
# target                      0
# cp_atypical angina          0
# cp_non-anginal              0
# cp_typical angina           0
# restecg_normal              0
# restecg_st-t abnormality    0
# slope_flat                  0
# slope_upsloping             0
# thal_normal                 0
# thal_reversable defect      0
# dtype: int64

# %%
df.describe()
# Out:
#               age         sex    trestbps        chol         fbs      thalch  \
# count  920.000000  920.000000  920.000000  920.000000  920.000000  920.000000
# mean    53.510870    0.789130  131.995652  199.908696    0.150000  137.692391
# std      9.424685    0.408148   18.451300  109.040171    0.357266   25.145235
# min     28.000000    0.000000    0.000000    0.000000    0.000000   60.000000
# 25%     47.000000    1.000000  120.000000  177.750000    0.000000  120.000000
# 50%     54.000000    1.000000  130.000000  223.000000    0.000000  140.000000
# 75%     60.000000    1.000000  140.000000  267.000000    0.000000  156.000000
# max     77.000000    1.000000  200.000000  603.000000    1.000000  202.000000
#
#             exang     oldpeak          ca      target  cp_atypical angina  \
# count  920.000000  920.000000  920.000000  920.000000          920.000000
# mean     0.366304    0.853261    0.227174    0.995652            0.189130
# std      0.482056    1.058049    0.628936    1.142693            0.391825
# min      0.000000   -2.600000    0.000000    0.000000            0.000000
# 25%      0.000000    0.000000    0.000000    0.000000            0.000000
# 50%      0.000000    0.500000    0.000000    1.000000            0.000000
# 75%      1.000000    1.500000    0.000000    2.000000            0.000000
# max      1.000000    6.200000    3.000000    4.000000            1.000000
#
#        cp_non-anginal  cp_typical angina  restecg_normal  \
# count      920.000000         920.000000      920.000000
# mean         0.221739           0.050000        0.601087
# std          0.415642           0.218063        0.489941
# min          0.000000           0.000000        0.000000
# 25%          0.000000           0.000000        0.000000
# 50%          0.000000           0.000000        1.000000
# 75%          0.000000           0.000000        1.000000
# max          1.000000           1.000000        1.000000
#
#        restecg_st-t abnormality  slope_flat  slope_upsloping  thal_normal  \
# count                920.000000  920.000000       920.000000   920.000000
# mean                   0.194565    0.710870         0.220652     0.741304
# std                    0.396081    0.453605         0.414912     0.438156
# min                    0.000000    0.000000         0.000000     0.000000
# 25%                    0.000000    0.000000         0.000000     0.000000
# 50%                    0.000000    1.000000         0.000000     1.000000
# 75%                    0.000000    1.000000         0.000000     1.000000
# max                    1.000000    1.000000         1.000000     1.000000
#
#        thal_reversable defect
# count              920.000000
# mean                 0.208696
# std                  0.406597
# min                  0.000000
# 25%                  0.000000
# 50%                  0.000000
# 75%                  0.000000
# max                  1.000000

# %%
df["target"].value_counts()
# Out:
# target
# 0    411
# 1    265
# 2    109
# 3    107
# 4     28
# Name: count, dtype: int64

# %%
df["target"] = df["target"].apply(lambda x: 1 if x > 0 else 0)

# %%
df["target"].value_counts()
# Out:
# target
# 1    509
# 0    411
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# age                         0
# sex                         0
# trestbps                    0
# chol                        0
# fbs                         0
# thalch                      0
# exang                       0
# oldpeak                     0
# ca                          0
# target                      0
# cp_atypical angina          0
# cp_non-anginal              0
# cp_typical angina           0
# restecg_normal              0
# restecg_st-t abnormality    0
# slope_flat                  0
# slope_upsloping             0
# thal_normal                 0
# thal_reversable defect      0
# dtype: int64

# %%
df.head()
# Out:
#    age  sex  trestbps   chol  fbs  thalch  exang  oldpeak   ca  target  \
# 0   63    1     145.0  233.0    1   150.0      0      2.3  0.0       0
# 1   67    1     160.0  286.0    0   108.0      1      1.5  3.0       1
# 2   67    1     120.0  229.0    0   129.0      1      2.6  2.0       1
# 3   37    1     130.0  250.0    0   187.0      0      3.5  0.0       0
# 4   41    0     130.0  204.0    0   172.0      0      1.4  0.0       0
#
#    cp_atypical angina  cp_non-anginal  cp_typical angina  restecg_normal  \
# 0                   0               0                  1               0
# 1                   0               0                  0               0
# 2                   0               0                  0               0
# 3                   0               1                  0               1
# 4                   1               0                  0               0
#
#    restecg_st-t abnormality  slope_flat  slope_upsloping  thal_normal  \
# 0                         0           0                0            0
# 1                         0           1                0            1
# 2                         0           1                0            0
# 3                         0           0                0            1
# 4                         0           0                1            1
#
#    thal_reversable defect
# 0                       0
# 1                       0
# 2                       1
# 3                       0
# 4                       0
